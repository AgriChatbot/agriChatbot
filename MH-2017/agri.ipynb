# %%
import pandas as pd

# %%
f = pd.read_csv('metric_test.csv')

# %%
t = pd.read_csv('metric_result.csv')

# %%
use = pd.concat([f,t],axis=1)

# %%
accuracy = sum(list(t['Truth']))

# %%
accuracy
# Out:
# 59

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
pattern = 'NP: {<NNS>?<NN>}'
cp = nltk.RegexpParser(pattern)

for sent in list(use['0'][:1]):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    cs = cp.parse(sent)
#     iob_tagged = tree2conlltags(cs)
#     pprint(iob_tagged)
    print(cs)
# Out:
# (S
#   (NP attack/NN)
#   of/IN
#   jassids/NNS
#   leaf/JJ
#   hoppers/NNS
#   on/IN
#   (NP cotton/NN))

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
import nltk

# %%
#doc = "Andrew Yan-Tak Ng is a Chinese American computer scientist.He is the former chief scientist at Baidu, where he led the company's Artificial Intelligence Group. He is an adjunct professor (formerly associate professor) at Stanford University. Ng is also the co-founder and chairman at Coursera, an online education platform. Andrew was born in the UK in 1976. His parents were both from Hong Kong."
doc = "drench in onion"
tokenized_doc = nltk.word_tokenize(doc)
 
# tag sentences and use nltk's Named Entity Chunker
tagged_sentences = nltk.pos_tag(tokenized_doc)
ne_chunked_sents = nltk.ne_chunk(tagged_sentences)

# extract all named entities
named_entities = []
for tagged_tree in ne_chunked_sents:
    if hasattr(tagged_tree, 'label'):
        entity_name = ' '.join(c[0] for c in tagged_tree.leaves()) #
        entity_type = tagged_tree.label() # get NE category
        named_entities.append((entity_name, entity_type))
        
print(named_entities)
# Out:
# []

# %%
# Out:
# [nltk_data] Downloading package words to /Users/namanjain/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
f1 = pd.read_csv('metric_test_1.csv')

# %%
f1
# Out:
#     Unnamed: 0                                                  0  \
# 0            0                            varieties og green gram
# 1            1                             fruit borer on brinjal
# 2            2                                govt schmes for cow
# 3            3                             attack of catterpillar
# 4            4                  asking about varieties of cow pea
# 5            5       farmer asked about market rate of red chilli
# 6            6                  attack of shoot borerin sugarcane
# 7            7                subsidy for onion storage structure
# 8            8                      asked about paddy market rate
# 9            9                     asked about maize growth spray
# 10          10                           market price of 18 46 00
# 11          11            asked about soyabean caterpiller attack
# 12          12  asked about attack of fungus and sucking pest ...
# 13          13  attack of sucking pest and fungal disease in o...
# 14          14                             for flowering on guava
# 15          15                  pre emergence herbicide in cotton
# 16          16                                   blight on cotton
# 17          17               asked about contact no of kosbad kvk
# 18          18                       attack of beetles on brinjal
# 19          19                        sandal wood nersory contact
# 20          20  asked about contact number of soil testing lab...
# 21          21  attack of sucking pest and fungal disease in c...
# 22          22                      attack of leaf minor on beans
# 23          23  farmer asked about irrigation scheduled for po...
# 24          24                asked about sowing time of chillies
# 25          25                    asking vbout reddning on cotton
# 26          26          sking about fertilizer dose for sugarcane
# 27          27                              flower drops of lemon
# 28          28  dr balasaheb sawant konkan krishi vidyapeeth c...
# 29          29                      asking intercroping in cotton
# ..         ...                                                ...
# 70          70                 asked about varieties of muskmelon
# 71          71                  asking about yellowing on soybean
# 72          72  farmer asked about attack of early shoot borer...
# 73          73            farmer asked about sheep goat insurance
# 74          74            asked about attack of whiteant on mango
# 75          75                                    variety of gnut
# 76          76                        attack of aphids on sorghum
# 77          77                                      onion variety
# 78          78                  attack of stem borar on sugarcane
# 79          79                 asked about market rate of brinjal
# 80          80                         sugarcane attack stim bore
# 81          81  asked about animal expert toll free contact nu...
# 82          82                 attack of pink boll worm on cotton
# 83          83            attack of thrips and jassids fungicides
# 84          84                             market rate for orange
# 85          85            asked about fertilizeer dose for cotton
# 86          86                                drenching on banana
# 87          87                                       fruit bvorer
# 88          88                    asked about black colour poutry
# 89          89                   asked about attack of leaf minor
# 90          90        asking about attack of caterpillar on lemon
# 91          91                soil testing lab sangali contact no
# 92          92                               bhendi planting time
# 93          93           tton asked about fertilizer spray on coo
# 94          94                             rust attack on brinjal
# 95          95                   asked about varieties of musturd
# 96          96         chhatrapati shivaji maharaj farmer s honor
# 97          97  mahatma phule krishi vidyapeeth college of agr...
# 98          98                                 attack of wilt mar
# 99          99                           fertilizer for acid lime
#
#                                                     1  \
# 0                   ['varieties og moong  = vaibhav']
# 1   ['spray proclaim 07 gm/15 liter of water(emame...
# 2        ['govt schmes for cow --- 25-33 % subsidey']
# 3   ['spray triazhophos 30 ml/15 liter water', 'sp...
# 4   ['new varieties -pusa do fasli, pusa barsati, ...
# 5   ['market rate of red chilli  - kolhapur-laxmip...
# 6      ['spray chloropyriphos 30ml/15 lit of water.']
# 7   ['25 % subsidy for  onion storage structure co...
# 8   ['paddy market rate=\tjayshriram\ttiroda\tquin...
# 9   ['spray 19.19.19 60 gram +microlla 30 ml + bav...
# 10       ['dap - 18:46:00 / 50 kg. bag\tiffco\t1100']
# 11     ['spray profenophos 20 ml/15 liter of water.']
# 12  ['for control  of fungus and sucking pest on p...
# 13  ['spray actra 5 gm + m-45 30 gm/15 lit of wate...
# 14  ['spray boom flower 30 ml/15 lit of water. (ni...
# 15  ['spray pendamethelene before sowing of crop',...
# 16  ['spray cabriotop 45 gm/15 liter of water-meti...
# 17  ['contact no. of kosbad kvk :\r\naddress: kosb...
# 18  ['spray quinolphos 30 ml / 15 litter of water ...
# 19  ['company name\t:\tchandana siri\r\ncontact pe...
# 20  ['contact number of soil testing laboratory  -...
# 21  ['spray actra 5 gm + m-45 30 gm/15 lit of wate...
# 22  ['spray trizophos 30 ml / 15 litter of water f...
# 23  ['?????? ????? ???? ???????? ??????? ?????????...
# 24  ['sowing time of  chillies - jauary -february .']
# 25  ['spray magnesium sulphate 60gm + 12:61:00 75g...
# 26  ['application of 10:26:26 1 bag + urea 20 kg +...
# 27  ['to stop flower  drops of lemon spray plano f...
# 28  ['dr. balasaheb sawant konkan krishi vidyapeet...
# 29  ['groundnut sb in summer garden cultivation 11...
# ..                                                ...
# 70  ['varieties of muskmelon - pusa sharbati , pus...
# 71  ['yellowing on soybean spray - microla 30 ml +...
# 72  ['for control of early shoot borer in sugarcan...
# 73  ['sheep & goat insurance = please contact \r\n...
# 74  ['for control of white ant/ termite on mango  ...
# 75  ['??????? ????-?????-??,??????,???? ??,????-??...
# 76  ['rijent 20 ml /15 liter water', 'spray asiphe...
# 77  ['improved onion variety puna fursungi, basava...
# 78  ['spray nuvan 20 ml / 15 liters of water ( dic...
# 79  ['market rate of  brinjal : 1000-1200 rupees/q...
# 80  ['spray avant 10 ml/15 lit of water.(indoxacar...
# 81  ['animal expert toll free contact number- 1800...
# 82  ['spray karate 15 ml / 15 litter of water for ...
# 83  ['spray actra 5 gm/15 liter of water (thiomith...
# 84  ['market rate for orange \tlocal\tamarawati-fr...
# 85  ['fertilizeer dose for cotton - 10;26;26 100 k...
# 86  ['by drip 19:19:19 3 kg + microlla  300 ml + h...
# 87  ['spray chloropyriphos 30ml(blaze (indofil))/1...
# 88               ['black colour poutry - kadknath .']
# 89  ['spray nim ark 30 ml / 15 liter of water.', '...
# 90  ['attack of caterpillar on lemon - spray chlor...
# 91  ['soil testing lab sangali contact no -- 0233-...
# 92  ['bhendi planting time = 15 janewari to 15 feb...
# 93         ['spray 00 52 34 60 gm /15 lit of water.']
# 94  ['spray m-45 30 gm /15 liter water.(mancozeb) ...
# 95  ['varieties of musturd  - pusa bold, acn- shat...
# 96  ["contact chhatrapati shivaji maharaj farmer's...
# 97  ['(020)25538489,25537033,25537038', 'mahatma p...
# 98  ['blue copper 30 gm +humic acid 30 ml(copper o...
# 99  ['use fym 20 kilo /ekar', '00 52 34 60 gm + mi...
#
#                                                     2  \
# 0                             varieties of green gram
# 1                                 brinjal fruit borer
# 2                                           cow breed
# 3                                 catterpillar attack
# 4               asking about new varieties of cow pea
# 5    farmer asked about market rate of cotton and tur
# 6                      shoot bore attack on sugarcane
# 7     asked about subsidy for onion storage structure
# 8                    asked about market rate of paddy
# 9                  asked about growth spray for maize
# 10                                       market price
# 11         asked about caterpiller attack on soyabean
# 12  asked about attack of sucking pest and fungus ...
# 13  attack of sucking pest and fungal disease in s...
# 14                                          flowering
# 15     adsked about pre emergence herbicide in cotton
# 16                                   blight on chilli
# 17                asked about baramati kvk contact no
# 18                             brinjal attack bligjht
# 19                       contact no of vnmau parbhani
# 20          asked soil testing lab contact number stl
# 21                  attack of sucking pest on cow pea
# 22                     attack of leaf minor of tomato
# 23         farmer asked about watering to pomegranate
# 24              asked about sowing time of watermelon
# 25                   asking about reddening on cotton
# 26                       fertilizer dose of sugarcane
# 27                           flower drops in chillies
# 28       dr balasaheb sawant konkan krishi vidyapeeth
# 29                   asking about reddening on cotton
# ..                                                ...
# 70                                    asked varieties
# 71                    asking about yellowing on paddy
# 72  farmer asked about attack of shoot borer in paddy
# 73                  farmer asked about crop insurance
# 74              asked about attack of virus on tomato
# 75                                variety of gingelly
# 76                      attack of aphids in groundnut
# 77                                   variety of onion
# 78                     attack of sugarcane stem boror
# 79                    asked about brinjal market rate
# 80                    attack of termites in sugarcane
# 81  asked about toll free animal expert contact nu...
# 82                 attack of pink boll worm in cotton
# 83               attack of thrips and jassids on pomo
# 84                                 orange market rate
# 85            asked about ferrtilizer dose for cotton
# 86                        drenching for banana plants
# 87                                       dragan fruit
# 88                             asked about black spot
# 89       asked about attack of leaf miner on dhaincha
# 90       asking about attack of caterpillar on papaya
# 91                        soil testing lab contact no
# 92                           watermelon planting time
# 93                       asked about fertilizer spray
# 94                      caterpiller attack on brinjal
# 95                                    asked varieties
# 96    chhatrapati shivaji maharaj farmer s honor plan
# 97  asked contact mahatma phule krishi vidyapeeth ...
# 98                                    wilt mar attack
# 99               fertilizer application for acid lime
#
#                                                     3
# 0   ['varieties of green gram - kopargaon vaibhav ...
# 1   ['fame=5ml,,15 liter of water', 'spray fame 5m...
# 2         ['cow breed--jersy,triveni,sindhi,sahival']
# 3   ['chloropyriphos 30ml + humic acid 30ml/15 lit...
# 4   ['new varieties of cow pea -kokan sadabahar,ko...
# 5   ['market rate of cotton - dhamangaon-rly-5300-...
# 6   ['chloropyriphos 30ml + humic acid 30ml/15 lit...
# 7   ['25 % subsidy for onion storage structure con...
# 8   ['rs 2000-2353/qtl paddy market rate gadchirol...
# 9   ['spray 19.19.19 60 gram +microlla 30 ml + bav...
# 10  ['market price\tlocal\taheri\tquintal\t180\t48...
# 11  ['spray chlorpyrifos 30ml/15 liter of water.',...
# 12  ['for control of sucking pest and fungus on po...
# 13  ['spray actra 5 gm + m-45 30 gm/15 lit of wate...
# 14  ['spray boom flower 20 ml/15 lit of water', 's...
# 15  ['pre emergence herbicide in cotton- pendameth...
# 16                 ['spray   m 45  2.5  gram /liter']
# 17  ['at post:malegaon khurd, tal.baramati dist.pu...
# 18  ['redomil gold=30gm+tata meda=5ml+microla=30ml...
# 19  ['vasantrao naik marathwada agriculture univer...
# 20  ['soil testing lab contact number stl 0241-243...
# 21  ['spray supar confidor 6 ml / 15 litter of wat...
# 22  ['spray trizophos 30 ml / 15 litter of water f...
# 23  ['?????? ????? ???? ???????? ??????? ?????????...
# 24  ['? ?????? ???-??????(???-???)\r\n?????? ?????...
# 25  ['spray - magnesium sulphate 60 gm + 13:00:45 ...
# 26  ['application of urea 1 bag + supar phospet 2 ...
# 27  ['to stop flower drops in chillies spray plano...
# 28  ['dr. balasaheb sawant konkan krishi vidyapeet...
# 29  ['spray - magnesium sulphate 60 gm + 13:00:45 ...
# ..                                                ...
# 70          ['tomato varieties=bhagyashri,dhanashri']
# 71  ['spray -  microla 45 ml + m 45 40 gm/15 liter...
# 72  ['for control of shoot borer in paddy =spray p...
# 73  ['visit to tao to getting detail information a...
# 74  ['for control of virus on tomato  spray kasu-b...
# 75  ['variety of til- akt-64, akt-101,tapi', 'vari...
# 76  ['spray rogar 15 ml + ??-45 30 ????? / 15  lit...
# 77  ['phule samrat,puna fursungi,basavant-780,panc...
# 78  ['use phoret 4 kg / acer for controlling sugar...
# 79  ['brinjal market rate=kolhapur-malkapur\t----\...
# 80  ['use phoret 4 kg / acer for controlling termi...
# 81  ['toll free animal expert contact number \r\n1...
# 82  ['spray spinosad 5 ml / 15 litter of water for...
# 83  ['spray super confidor 10 ml /15 liter water(i...
# 84  ['orange market rate--2250 / qintal', 'orange ...
# 85  ['12:61:00 60 gram + microlla 30 milee in 15 l...
# 86  ['drenhching blue copper 500 gm + humic acid 5...
# 87  ['dragan fruit  \r\ndragan fruit  - address: p...
# 88  ['spray benoil spraying with 1 g / liter of wa...
# 89  ['for control of  leaf miner on dhaincha  spra...
# 90  ['chloropyriphos 30ml + humic acid 30ml/15 lit...
# 91  ['soil testing lab contact no---07262-241496',...
# 92  ['watermelon planting time = 15 janewari to 15...
# 93  ['spray 00 52 34 60 gm + microla- 30 mili /15 ...
# 94             ['spray proclaim 5gm/15lit of water.']
# 95          ['tomato varieties=bhagyashri,dhanashri']
# 96  ["contact chhatrapati shivaji maharaj farmer's...
# 97  ['mahatma phule krishi vidyapeeth-rahuri,ahmed...
# 98  ['spray m 45 30 gm + microla 30 ml  /15 liter ...
# 99  ['application of 00 52 34 4 kg /acre through d...
#
# [100 rows x 5 columns]

# %%
<p style="text-align: justify; color: rgb(4, 12, 251);">  1/2117, Street No. 18, Near Pal Chowk, Ram Nagar, Shahdara, Delhi - 110032</p>
